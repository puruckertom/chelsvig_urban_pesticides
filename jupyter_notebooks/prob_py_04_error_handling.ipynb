# %%
from pyswmm import Simulation
import swmmtoolbox.swmmtoolbox as swmmtoolbox
import os, dask, shutil, time, pandas as pd, numpy as np
# done on work computer
os.chdir("C:/Users/jstelman/Git/chelsvig_urban_pesticides/src/")

# %%
from path_names import dir_path
from pyswmm.lib import DLL_SELECTION
from prpy_bookkeeping import *
loginfo = log_prefixer("04")
# Out:
# main_path   C:\Users\jstelman\Git\chelsvig_urban_pesticides
# dir_path    C:\Users\jstelman\Git\chelsvig_urban_pesticides\probabilistic_python
# exe_path    C:\Users\jstelman\Git\chelsvig_urban_pesticides\probabilistic_python\exe
# swmm_path   C:\Users\jstelman\Git\chelsvig_urban_pesticides\probabilistic_python\input\swmm
# inp_path    C:\Users\jstelman\Git\chelsvig_urban_pesticides\probabilistic_python\input\swmm\NPlesantCreek.inp
# bin_path    C:\Users\jstelman\Git\chelsvig_urban_pesticides\probabilistic_python\input\swmm\NPlesantCreek.out
# vvwm_path   C:\Users\jstelman\Git\chelsvig_urban_pesticides\probabilistic_python\input\vvwm
# wet_path    C:\Users\jstelman\Git\chelsvig_urban_pesticides\probabilistic_python\weather

# %%
# number of simulations
nsims = 1

# %%
inp_dir_prefix = os.path.join(dir_path, "input", "swmm", "input_")
print(inp_dir_prefix)
# save the path for the original dynamic link library
dll_path = DLL_SELECTION()
# save its base name (just the name of the file)
dll_bn = os.path.basename(dll_path)
# save the path to a new folder where copies of dll will be stored upon creation
dll_dir = os.path.join(dir_path, "input", "swmm", "dll")
# make sure that folder exists. If it doesn't, create it.
if not os.path.exists(dll_dir):
    loginfo("Creating directory <" + dll_dir + ">.")
    print("Creating <dll/> directory.")
    os.mkdir(dll_dir)
# Out:
# C:\Users\jstelman\Git\chelsvig_urban_pesticides\probabilistic_python\input\swmm\input_

# %%
i=1
dll_i = dll_bn[:dll_bn.rindex(".")] + '-' + str(i) + dll_bn[dll_bn.rindex("."):]
lib_path = os.path.join(dll_dir, dll_i)
# create 1-time-use dll file copy
shutil.copyfile(dll_path, lib_path)
# specify the directory with the file pyswmm needs by attaching the folder id to the rest of the folder's absolute path
sim_dir = inp_dir_prefix + str(i)
# specify the actual file pyswmm needs
sim_path = os.path.join(sim_dir, r'JS_NPlesantCreek.inp')
#print("Simulation input file found:", sim_path)
# specify the file that pyswmm will (over)write with output after running the probabilistic simulation
sim_bin_path = os.path.join(sim_dir, "eh_test_JS_NPlesantCreek.out")
# delete pre-existing .out, if present, in order to run swmm agreeably
if os.path.exists(sim_bin_path):
    loginfo("Deleting current copy of <" + sim_bin_path + "> so new copy can be created.")
    #print("Deleting current copy of <NPlesantCreek.out> so new copy can be created.")
    os.remove(sim_bin_path)
# load the model {no interaction, write (binary) results to <JS_NPlesantCreek.out>, use the specified dll}
sim = Simulation(inputfile=sim_path, reportfile=None, outputfile=sim_bin_path, swmm_lib_path=lib_path)

# %%
sim.execute()
# Out:
# ... SWMM Version 5.3.0.dev0
# ... Run Complete

# %%
lab1 = 'subcatchment,,Runoff_rate'
lab2 = 'subcatchment,,Bifenthrin'
runf_stack = swmmtoolbox.extract(sim_bin_path, lab1)
bif_stack = swmmtoolbox.extract(sim_bin_path, lab2)

# %%
runf_stack.head()
# Out:
#             subcatchment_S1_Runoff_rate  subcatchment_S2_Runoff_rate  \
# 2009-01-02                          0.0                          0.0
# 2009-01-03                          0.0                          0.0
# 2009-01-04                          0.0                          0.0
# 2009-01-05                          0.0                          0.0
# 2009-01-06                          0.0                          0.0
#
#             subcatchment_S3_Runoff_rate  subcatchment_S4_Runoff_rate  \
# 2009-01-02                          0.0                          0.0
# 2009-01-03                          0.0                          0.0
# 2009-01-04                          0.0                          0.0
# 2009-01-05                          0.0                          0.0
# 2009-01-06                          0.0                          0.0
#
#             subcatchment_S5_Runoff_rate  subcatchment_S6_Runoff_rate  \
# 2009-01-02                          0.0                          0.0
# 2009-01-03                          0.0                          0.0
# 2009-01-04                          0.0                          0.0
# 2009-01-05                          0.0                          0.0
# 2009-01-06                          0.0                          0.0
#
#             subcatchment_S7_Runoff_rate  subcatchment_S8_Runoff_rate  \
# 2009-01-02                          0.0                          0.0
# 2009-01-03                          0.0                          0.0
# 2009-01-04                          0.0                          0.0
# 2009-01-05                          0.0                          0.0
# 2009-01-06                          0.0                          0.0
#
#             subcatchment_S9_Runoff_rate  subcatchment_S10_Runoff_rate  ...  \
# 2009-01-02                          0.0                           0.0  ...
# 2009-01-03                          0.0                           0.0  ...
# 2009-01-04                          0.0                           0.0  ...
# 2009-01-05                          0.0                           0.0  ...
# 2009-01-06                          0.0                           0.0  ...
#
#             subcatchment_S104_Runoff_rate  subcatchment_S105_Runoff_rate  \
# 2009-01-02                            0.0                            0.0
# 2009-01-03                            0.0                            0.0
# 2009-01-04                            0.0                            0.0
# 2009-01-05                            0.0                            0.0
# 2009-01-06                            0.0                            0.0
#
#             subcatchment_S106_Runoff_rate  subcatchment_S107_Runoff_rate  \
# 2009-01-02                            0.0                            0.0
# 2009-01-03                            0.0                            0.0
# 2009-01-04                            0.0                            0.0
# 2009-01-05                            0.0                            0.0
# 2009-01-06                            0.0                            0.0
#
#             subcatchment_S108_Runoff_rate  subcatchment_S109_Runoff_rate  \
# 2009-01-02                            0.0                            0.0
# 2009-01-03                            0.0                            0.0
# 2009-01-04                            0.0                            0.0
# 2009-01-05                            0.0                            0.0
# 2009-01-06                            0.0                            0.0
#
#             subcatchment_S110_Runoff_rate  subcatchment_S111_Runoff_rate  \
# 2009-01-02                            0.0                            0.0
# 2009-01-03                            0.0                            0.0
# 2009-01-04                            0.0                            0.0
# 2009-01-05                            0.0                            0.0
# 2009-01-06                            0.0                            0.0
#
#             subcatchment_S112_Runoff_rate  subcatchment_S113_Runoff_rate
# 2009-01-02                            0.0                            0.0
# 2009-01-03                            0.0                            0.0
# 2009-01-04                            0.0                            0.0
# 2009-01-05                            0.0                            0.0
# 2009-01-06                            0.0                            0.0
#
# [5 rows x 113 columns]

# %%
runf_davg = runf_stack.resample('D').mean()
bif_davg = bif_stack.resample('D').mean()

# %%
runf_davg.head()
# Out:
#             subcatchment_S1_Runoff_rate  subcatchment_S2_Runoff_rate  \
# 2009-01-02                          0.0                          0.0
# 2009-01-03                          0.0                          0.0
# 2009-01-04                          0.0                          0.0
# 2009-01-05                          0.0                          0.0
# 2009-01-06                          0.0                          0.0
#
#             subcatchment_S3_Runoff_rate  subcatchment_S4_Runoff_rate  \
# 2009-01-02                          0.0                          0.0
# 2009-01-03                          0.0                          0.0
# 2009-01-04                          0.0                          0.0
# 2009-01-05                          0.0                          0.0
# 2009-01-06                          0.0                          0.0
#
#             subcatchment_S5_Runoff_rate  subcatchment_S6_Runoff_rate  \
# 2009-01-02                          0.0                          0.0
# 2009-01-03                          0.0                          0.0
# 2009-01-04                          0.0                          0.0
# 2009-01-05                          0.0                          0.0
# 2009-01-06                          0.0                          0.0
#
#             subcatchment_S7_Runoff_rate  subcatchment_S8_Runoff_rate  \
# 2009-01-02                          0.0                          0.0
# 2009-01-03                          0.0                          0.0
# 2009-01-04                          0.0                          0.0
# 2009-01-05                          0.0                          0.0
# 2009-01-06                          0.0                          0.0
#
#             subcatchment_S9_Runoff_rate  subcatchment_S10_Runoff_rate  ...  \
# 2009-01-02                          0.0                           0.0  ...
# 2009-01-03                          0.0                           0.0  ...
# 2009-01-04                          0.0                           0.0  ...
# 2009-01-05                          0.0                           0.0  ...
# 2009-01-06                          0.0                           0.0  ...
#
#             subcatchment_S104_Runoff_rate  subcatchment_S105_Runoff_rate  \
# 2009-01-02                            0.0                            0.0
# 2009-01-03                            0.0                            0.0
# 2009-01-04                            0.0                            0.0
# 2009-01-05                            0.0                            0.0
# 2009-01-06                            0.0                            0.0
#
#             subcatchment_S106_Runoff_rate  subcatchment_S107_Runoff_rate  \
# 2009-01-02                            0.0                            0.0
# 2009-01-03                            0.0                            0.0
# 2009-01-04                            0.0                            0.0
# 2009-01-05                            0.0                            0.0
# 2009-01-06                            0.0                            0.0
#
#             subcatchment_S108_Runoff_rate  subcatchment_S109_Runoff_rate  \
# 2009-01-02                            0.0                            0.0
# 2009-01-03                            0.0                            0.0
# 2009-01-04                            0.0                            0.0
# 2009-01-05                            0.0                            0.0
# 2009-01-06                            0.0                            0.0
#
#             subcatchment_S110_Runoff_rate  subcatchment_S111_Runoff_rate  \
# 2009-01-02                            0.0                            0.0
# 2009-01-03                            0.0                            0.0
# 2009-01-04                            0.0                            0.0
# 2009-01-05                            0.0                            0.0
# 2009-01-06                            0.0                            0.0
#
#             subcatchment_S112_Runoff_rate  subcatchment_S113_Runoff_rate
# 2009-01-02                            0.0                            0.0
# 2009-01-03                            0.0                            0.0
# 2009-01-04                            0.0                            0.0
# 2009-01-05                            0.0                            0.0
# 2009-01-06                            0.0                            0.0
#
# [5 rows x 113 columns]

# %%
runf_davg.index
# Out:
# DatetimeIndex(['2009-01-02', '2009-01-03', '2009-01-04', '2009-01-05',
#                '2009-01-06', '2009-01-07', '2009-01-08', '2009-01-09',
#                '2009-01-10', '2009-01-11',
#                ...
#                '2009-12-22', '2009-12-23', '2009-12-24', '2009-12-25',
#                '2009-12-26', '2009-12-27', '2009-12-28', '2009-12-29',
#                '2009-12-30', '2009-12-31'],
#               dtype='datetime64[ns]', length=364, freq='D')

# %%
pd.DataFrame(data=np.nan,
             index=pd.DatetimeIndex(pd.date_range(start='1/1/2009', periods=3287, freq='D')),
             columns=["subcatchment_S"+str(s)+"_Runoff_rate" for s in range(1,114)]
            )
# Out:
#             subcatchment_S1_Runoff_rate  subcatchment_S2_Runoff_rate  \
# 2009-01-01                          NaN                          NaN
# 2009-01-02                          NaN                          NaN
# 2009-01-03                          NaN                          NaN
# 2009-01-04                          NaN                          NaN
# 2009-01-05                          NaN                          NaN
# ...                                 ...                          ...
# 2017-12-27                          NaN                          NaN
# 2017-12-28                          NaN                          NaN
# 2017-12-29                          NaN                          NaN
# 2017-12-30                          NaN                          NaN
# 2017-12-31                          NaN                          NaN
#
#             subcatchment_S3_Runoff_rate  subcatchment_S4_Runoff_rate  \
# 2009-01-01                          NaN                          NaN
# 2009-01-02                          NaN                          NaN
# 2009-01-03                          NaN                          NaN
# 2009-01-04                          NaN                          NaN
# 2009-01-05                          NaN                          NaN
# ...                                 ...                          ...
# 2017-12-27                          NaN                          NaN
# 2017-12-28                          NaN                          NaN
# 2017-12-29                          NaN                          NaN
# 2017-12-30                          NaN                          NaN
# 2017-12-31                          NaN                          NaN
#
#             subcatchment_S5_Runoff_rate  subcatchment_S6_Runoff_rate  \
# 2009-01-01                          NaN                          NaN
# 2009-01-02                          NaN                          NaN
# 2009-01-03                          NaN                          NaN
# 2009-01-04                          NaN                          NaN
# 2009-01-05                          NaN                          NaN
# ...                                 ...                          ...
# 2017-12-27                          NaN                          NaN
# 2017-12-28                          NaN                          NaN
# 2017-12-29                          NaN                          NaN
# 2017-12-30                          NaN                          NaN
# 2017-12-31                          NaN                          NaN
#
#             subcatchment_S7_Runoff_rate  subcatchment_S8_Runoff_rate  \
# 2009-01-01                          NaN                          NaN
# 2009-01-02                          NaN                          NaN
# 2009-01-03                          NaN                          NaN
# 2009-01-04                          NaN                          NaN
# 2009-01-05                          NaN                          NaN
# ...                                 ...                          ...
# 2017-12-27                          NaN                          NaN
# 2017-12-28                          NaN                          NaN
# 2017-12-29                          NaN                          NaN
# 2017-12-30                          NaN                          NaN
# 2017-12-31                          NaN                          NaN
#
#             subcatchment_S9_Runoff_rate  subcatchment_S10_Runoff_rate  ...  \
# 2009-01-01                          NaN                           NaN  ...
# 2009-01-02                          NaN                           NaN  ...
# 2009-01-03                          NaN                           NaN  ...
# 2009-01-04                          NaN                           NaN  ...
# 2009-01-05                          NaN                           NaN  ...
# ...                                 ...                           ...  ...
# 2017-12-27                          NaN                           NaN  ...
# 2017-12-28                          NaN                           NaN  ...
# 2017-12-29                          NaN                           NaN  ...
# 2017-12-30                          NaN                           NaN  ...
# 2017-12-31                          NaN                           NaN  ...
#
#             subcatchment_S104_Runoff_rate  subcatchment_S105_Runoff_rate  \
# 2009-01-01                            NaN                            NaN
# 2009-01-02                            NaN                            NaN
# 2009-01-03                            NaN                            NaN
# 2009-01-04                            NaN                            NaN
# 2009-01-05                            NaN                            NaN
# ...                                   ...                            ...
# 2017-12-27                            NaN                            NaN
# 2017-12-28                            NaN                            NaN
# 2017-12-29                            NaN                            NaN
# 2017-12-30                            NaN                            NaN
# 2017-12-31                            NaN                            NaN
#
#             subcatchment_S106_Runoff_rate  subcatchment_S107_Runoff_rate  \
# 2009-01-01                            NaN                            NaN
# 2009-01-02                            NaN                            NaN
# 2009-01-03                            NaN                            NaN
# 2009-01-04                            NaN                            NaN
# 2009-01-05                            NaN                            NaN
# ...                                   ...                            ...
# 2017-12-27                            NaN                            NaN
# 2017-12-28                            NaN                            NaN
# 2017-12-29                            NaN                            NaN
# 2017-12-30                            NaN                            NaN
# 2017-12-31                            NaN                            NaN
#
#             subcatchment_S108_Runoff_rate  subcatchment_S109_Runoff_rate  \
# 2009-01-01                            NaN                            NaN
# 2009-01-02                            NaN                            NaN
# 2009-01-03                            NaN                            NaN
# 2009-01-04                            NaN                            NaN
# 2009-01-05                            NaN                            NaN
# ...                                   ...                            ...
# 2017-12-27                            NaN                            NaN
# 2017-12-28                            NaN                            NaN
# 2017-12-29                            NaN                            NaN
# 2017-12-30                            NaN                            NaN
# 2017-12-31                            NaN                            NaN
#
#             subcatchment_S110_Runoff_rate  subcatchment_S111_Runoff_rate  \
# 2009-01-01                            NaN                            NaN
# 2009-01-02                            NaN                            NaN
# 2009-01-03                            NaN                            NaN
# 2009-01-04                            NaN                            NaN
# 2009-01-05                            NaN                            NaN
# ...                                   ...                            ...
# 2017-12-27                            NaN                            NaN
# 2017-12-28                            NaN                            NaN
# 2017-12-29                            NaN                            NaN
# 2017-12-30                            NaN                            NaN
# 2017-12-31                            NaN                            NaN
#
#             subcatchment_S112_Runoff_rate  subcatchment_S113_Runoff_rate
# 2009-01-01                            NaN                            NaN
# 2009-01-02                            NaN                            NaN
# 2009-01-03                            NaN                            NaN
# 2009-01-04                            NaN                            NaN
# 2009-01-05                            NaN                            NaN
# ...                                   ...                            ...
# 2017-12-27                            NaN                            NaN
# 2017-12-28                            NaN                            NaN
# 2017-12-29                            NaN                            NaN
# 2017-12-30                            NaN                            NaN
# 2017-12-31                            NaN                            NaN
#
# [3287 rows x 113 columns]

# %%
'''
Makes arrangements for executing the following task:
    Run specified probabilistic simulations in SWMM from the specified .inp file. Save output in equivalently named .out file.
Inputs:
    i <integer> -indicates input folder id number (for now, will only ever be 1-5).-
Immediate Output:
    <dask.delayed.Delayed> -arrangements for executing the task when commanded at a future time (by the 'compute()' function)
Computable Output:
    <string> -message indicating that the simulation has been completed on the .inp file in the 'i' input folder.-
'''

# this decorator is the first step in using dask to parallelize swmm simulations
@dask.delayed
def delay_job(i):
    loginfo("Simmulation " + str(i) + " of " + str(nsims))
    # create path to the 1-time-use dll file we are going to create
    dll_i = dll_bn[:dll_bn.rindex(".")] + '-' + str(i) + dll_bn[dll_bn.rindex("."):]
    lib_path = os.path.join(dll_dir, dll_i)
    # create 1-time-use dll file copy
    shutil.copyfile(dll_path, lib_path)
    # specify the directory with the file pyswmm needs by attaching the folder id to the rest of the folder's absolute path
    sim_dir = inp_dir_prefix + str(i)
    # specify the actual file pyswmm needs
    sim_path = os.path.join(sim_dir, r'JsS_NPlesantCreek.inp')
    #print("Simulation input file found:", sim_path)
    # specify the file that pyswmm will (over)write with output after running the probabilistic simulation
    sim_bin_path = os.path.join(sim_dir, "JdS_NPlesantCreek.out")
    # delete pre-existing .out, if present, in order to run swmm agreeably
    if os.path.exists(sim_bin_path):
        loginfo("Deleting current copy of <" + sim_bin_path + "> so new copy can be created.")
        #print("Deleting current copy of <NPlesantCreek.out> so new copy can be created.")
        os.remove(sim_bin_path)
    # stagger starting times 1 sec apart
    time.sleep(i)
    # load the model {no interaction, write (binary) results to <JS_NPlesantCreek.out>, use the specified dll}
    sim = Simulation(inputfile=sim_path, reportfile=None, outputfile=sim_bin_path, swmm_lib_path=lib_path)
    # simulate the loaded model
    loginfo("Executing SWMM simmulation with no interaction. Input from <" + sim_path + ">. Will store output in <" + sim_bin_path + ">.")
    # sim.execute()
    try:
        with sim as s:
            for step in s:
                pass
        # extract swmm outputs with swmmtoolbox and delete expensive binary files
        lab1 = 'subcatchment,,Runoff_rate'
        lab2 = 'subcatchment,,Bifenthrin'
        runf_stack = swmmtoolbox.extract(sim_bin_path, lab1)
        bif_stack = swmmtoolbox.extract(sim_bin_path, lab2)

        loginfo("Deleting <" + sim_bin_path + "> to free up memory.")
        os.remove(sim_bin_path)
        loginfo("Deleting <" + dll_i + "> to free up memory.")
        os.system("rm " + lib_path)
        print("Deleted <input_" + str(i) + "/JS_NPlesantCreek.out> and <" + dll_i + "> to free up memory.")    

        # compute and export daily averages to csv files and finish
        runf_davg = runf_stack.resample('D').mean()
        bif_davg = bif_stack.resample('D').mean()

    except SWMMException:
        loginfo("Simulation <" + sim_bin_path + "> failed. Proceeding with NaN substitution.")
        
        loginfo("Deleting <" + sim_bin_path + "> to free up memory.")
        os.remove(sim_bin_path)
        loginfo("Deleting <" + dll_i + "> to free up memory.")
        os.system("rm " + lib_path)
        print("Deleted <input_" + str(i) + "/JS_NPlesantCreek.out> and <" + dll_i + "> to free up memory.")    

        # compute and export daily averages to csv files and finish

        runf_davg = pd.DataFrame(data=np.nan,
                                 index=pd.DatetimeIndex(pd.date_range(start='1/1/2009', periods=3287, freq='D')),
                                 columns=["subcatchment_S"+str(s)+"_Runoff_rate" for s in range(1,114)]
                                )
        bif_davg = pd.DataFrame(data=np.nan,
                                 index=pd.DatetimeIndex(pd.date_range(start='1/1/2009', periods=3287, freq='D')),
                                 columns=["subcatchment_S"+str(s)+"_Bifenthrin_rate" for s in range(1,114)]
                                )
    print(save_and_finish(runf_davg, os.path.join(sim_dir, "swmm_output_davg_runf.csv")))
    print(save_and_finish(bif_davg, os.path.join(sim_dir, "swmm_output_davg_bif.csv")))
    # msg1 and msg2 text will be the same, but we must do both to save both csvs
    
    # a message to indicate success
    return("file " + str(i) + " simulated!")

# %%
# set up the processes for each of the 5 simulations
delayed_tasks = [delay_job(x) for x in range(1, nsims+1)]

# %%
# hit go!
dask.delayed(print)(delayed_tasks).compute()
# Out:
# ---------------------------------------------------------------------------
# SWMMException                             Traceback (most recent call last)
# <ipython-input-12-d5bea73a0514> in <module>
#       1 # hit go!
# ----> 2 dask.delayed(print)(delayed_tasks).compute()
#
# ~\Anaconda3\envs\swmm1\lib\site-packages\dask\base.py in compute(self, **kwargs)
#     164         dask.base.compute
#     165         """
# --> 166         (result,) = compute(self, traverse=False, **kwargs)
#     167         return result
#     168
#
# ~\Anaconda3\envs\swmm1\lib\site-packages\dask\base.py in compute(*args, **kwargs)
#     442         postcomputes.append(x.__dask_postcompute__())
#     443
# --> 444     results = schedule(dsk, keys, **kwargs)
#     445     return repack([f(r, *a) for r, (f, a) in zip(results, postcomputes)])
#     446
#
# ~\Anaconda3\envs\swmm1\lib\site-packages\dask\threaded.py in get(dsk, result, cache, num_workers, pool, **kwargs)
#      74                 pools[thread][num_workers] = pool
#      75
# ---> 76     results = get_async(
#      77         pool.apply_async,
#      78         len(pool._pool),
#
# ~\Anaconda3\envs\swmm1\lib\site-packages\dask\local.py in get_async(apply_async, num_workers, dsk, result, cache, get_id, rerun_exceptions_locally, pack_exception, raise_exception, callbacks, dumps, loads, **kwargs)
#     484                         _execute_task(task, data)  # Re-execute locally
#     485                     else:
# --> 486                         raise_exception(exc, tb)
#     487                 res, worker_id = loads(res_info)
#     488                 state["cache"][key] = res
#
# ~\Anaconda3\envs\swmm1\lib\site-packages\dask\local.py in reraise(exc, tb)
#     314     if exc.__traceback__ is not tb:
#     315         raise exc.with_traceback(tb)
# --> 316     raise exc
#     317
#     318
#
# ~\Anaconda3\envs\swmm1\lib\site-packages\dask\local.py in execute_task(key, task_info, dumps, loads, get_id, pack_exception)
#     220     try:
#     221         task, data = loads(task_info)
# --> 222         result = _execute_task(task, data)
#     223         id = get_id()
#     224         result = dumps((result, id))
#
# ~\Anaconda3\envs\swmm1\lib\site-packages\dask\core.py in _execute_task(arg, cache, dsk)
#     119         # temporaries by their reference count and can execute certain
#     120         # operations in-place.
# --> 121         return func(*(_execute_task(a, cache) for a in args))
#     122     elif not ishashable(arg):
#     123         return arg
#
# <ipython-input-10-3099e173ef4a> in delay_job(i)
#      34     time.sleep(i)
#      35     # load the model {no interaction, write (binary) results to <JS_NPlesantCreek.out>, use the specified dll}
# ---> 36     sim = Simulation(inputfile=sim_path, reportfile=None, outputfile=sim_bin_path, swmm_lib_path=lib_path)
#      37     # simulate the loaded model
#      38     loginfo("Executing SWMM simmulation with no interaction. Input from <" + sim_path + ">. Will store output in <" + sim_bin_path + ">.")
#
# ~\Anaconda3\envs\swmm1\lib\site-packages\pyswmm\simulation.py in __init__(self, inputfile, reportfile, outputfile, swmm_lib_path)
#      67                  swmm_lib_path=None):
#      68         self._model = PySWMM(inputfile, reportfile, outputfile, swmm_lib_path)
# ---> 69         self._model.swmm_open()
#      70         self._isOpen = True
#      71         self._advance_seconds = None
#
# ~\Anaconda3\envs\swmm1\lib\site-packages\pyswmm\swmm5.py in swmm_open(self, inpfile, rptfile, binfile)
#     265             ctypes.c_char_p(six.b(inpfile)),
#     266             ctypes.c_char_p(six.b(rptfile)), ctypes.c_char_p(six.b(binfile)))
# --> 267         self._error_check(errcode)
#     268         self.fileLoaded = True
#     269
#
# ~\Anaconda3\envs\swmm1\lib\site-packages\pyswmm\swmm5.py in _error_check(self, errcode)
#     163
#     164         if errcode != 0:
# --> 165             raise SWMMException(errcode, self._error_message(errcode))
#     166
#     167     def swmmExec(self, inpfile=None, rptfile=None, binfile=None):
#
# SWMMException:
#   ERROR 303: cannot open input file.
